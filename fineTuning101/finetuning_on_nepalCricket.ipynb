# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from datasets import Dataset

# 1. PREPARE THE DATA
# Load your essay from the .txt file
with open("NepalCricket.txt", "r", encoding="utf-8") as f:
    essay_text = f.read()

# %%
essay_text
# Out:
# " Nepal’s Journey in the T20I World Cup\n\nCricket in Nepal is more than a sport — it is a shared national emotion. Over the past two decades, the rise of the Nepali national team from associate obscurity to global recognition has been dramatic, inspiring, and at times heartbreaking. The country’s participation in the ICC Men's T20 World Cup symbolizes not just sporting achievement but the dreams of millions of fans who see cricket as Nepal’s voice on the world stage.\n\n\n\n Early Foundations: Passion Before Professionalism\n\nCricket arrived in Nepal during the Rana era, but it remained limited to elites for decades. Real change began after the establishment of the Cricket Association of Nepal, which slowly expanded grassroots participation. For many years Nepal competed in lower divisions of international cricket, facing logistical challenges, lack of infrastructure, and limited funding.\n\nYet the one thing Nepal never lacked was passion.\n\nCrowds filled grounds even for small tournaments. Players often trained without proper facilities, equipment, or salaries. Unlike major cricketing nations, Nepal’s growth came not from systems but from raw national enthusiasm.\n\n\n\n The Historic Breakthrough — 2014 Qualification\n\nThe defining moment came in 2013 when Nepal qualified for the 2014 T20 World Cup held in Bangladesh. For the first time in history, Nepal would play in a senior ICC global tournament.\n\nCaptain Paras Khadka became the face of a generation. Calm, disciplined, and fearless, he led a young team that believed it belonged among stronger cricketing nations.\n\nNepal was placed in a difficult group alongside Hong Kong, Afghanistan, and Bangladesh.\n\n*(Note: entity repetition rule — Bangladesh already used once, so avoid second wrap in final text; continue narrative normally.)*\n\nNepal’s very first World Cup match produced history — a victory over Hong Kong. The team followed with a thrilling win against Afghanistan. Although Nepal narrowly missed qualification to the Super 10 stage due to net run rate, the campaign was widely considered one of the most remarkable debut performances in tournament history.\n\nFor the first time, the global cricket community recognized Nepal as more than just an associate participant — it was a competitive side.\n\n\n\n The Lost Years — Suspension and Struggle\n\nIronically, after achieving international fame, Nepal entered its darkest cricketing period.\n\nIn 2016, the International Cricket Council suspended Nepal due to administrative issues within its board. The suspension meant:\n\n* No official bilateral matches\n* Loss of funding\n* Stagnation of player development\n* Uncertainty about future tournaments\n\nMany feared Nepal’s golden generation would disappear before reaching maturity.\n\nBut something unusual happened — fan support intensified. Domestic tournaments like Everest Premier League gained popularity. Young players continued practicing without international exposure. Cricket survived not because of governance, but because of public belief.\n\n\n\n Rebuilding Era — New Heroes Emerge\n\nAfter the suspension was lifted in 2019, Nepal entered a rebuilding phase. A new generation emerged led by Rohit Paudel and star leg-spinner Sandeep Lamichhane.\n\nLamichhane became Nepal’s first global franchise cricket star, playing leagues around the world. His success changed perceptions — Nepali players could compete internationally not only as a team but individually.\n\nMeanwhile, Rohit Paudel represented a transition in leadership — from pioneering survival to competitive ambition. Under new leadership, Nepal’s strategy evolved:\n\n**Earlier Era:** defensive, disciplined, survival cricket\n**Modern Era:** aggressive batting + spin-dominant bowling\n\nThis shift was necessary because T20 cricket rewards boldness over caution.\n\n\n\n Road to the 2024 T20 World Cup\n\nQualification for the 2024 tournament required navigating intense regional qualifiers. Nepal competed against  ...

# %%
# We wrap the text in a dataset format the AI library understands
# We repeat it a few times in the list so the 'batch' isn't empty
data = {"text": [essay_text] * 10} 
dataset = Dataset.from_dict(data)

# %%
# 2. INITIALIZE MODEL & TOKENIZER
model_name = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = GPT2LMHeadModel.from_pretrained(model_name)

# GPT-2 doesn't have a padding token by default, so we use the 'end of text' token
tokenizer.pad_token = tokenizer.eos_token

# %%
# 3. TOKENIZE THE ESSAY
def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True, padding="max_length", max_length=512)

tokenized_dataset = dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/10 [00:00<?, ? examples/s]

# %%
# 4. SET TRAINING ARGUMENTS
# Since the essay is tiny, we increase 'num_train_epochs' so the AI sees it often
training_args = TrainingArguments(
    output_dir="./nepal_cricket_model",
    overwrite_output_dir=True,
    num_train_epochs=20,           # High epochs for a tiny dataset
    per_device_train_batch_size=2,
    save_steps=100,
    logging_steps=10,
    learning_rate=5e-5,            # A gentle nudge to the brain
    weight_decay=0.01,
)

# %%
# 5. THE TRAINER
# DataCollatorForLanguageModeling handles shifting labels for 'next word' prediction
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=tokenized_dataset,
)

# %%
# 6. START FINE-TUNING
print("Starting the journey...")
trainer.train()
# Out:
# Starting the journey...
# c:\Users\bisha\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 10:32, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.704900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.061800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.275200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.072700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.025000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.013100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.011800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.012900</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=0.42167734205722807, metrics={'train_runtime': 641.6679, 'train_samples_per_second': 0.312, 'train_steps_per_second': 0.156, 'total_flos': 52258406400000.0, 'train_loss': 0.42167734205722807, 'epoch': 20.0})

# %%
# 7. SAVE YOUR NEW MODEL
trainer.save_model("./nepal_cricket_model")
tokenizer.save_pretrained("./nepal_cricket_model")
print("Model graduated!")
# Out:
# Model graduated!
